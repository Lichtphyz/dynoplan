# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# !pip install seaborn

# %%
df = pd.read_csv("/home/dlicht/SCU/MotionPlanning/FinalProject/dynoplan/results_new/summary/summary_2026-03-19--16-51-34.csv")
# df = pd.read_csv("/home/dlicht/SCU/MotionPlanning/FinalProject/dynoplan/results_new/summary/summary_2026-03-19--18-54-48.csv")
df['alg'] = df['alg'].replace({"sst_rrt_v0":"RRT",
                                "sst_v0":"SST",
                                "idbastar_v0":"idbA*"})
df = df.replace([np.inf, -np.inf], np.nan)
df = df[['alg',  'time_first_solution', 'cost_first_solution',  'cost_at_01', 'cost_at_05', 'cost_at_10', 'cost_at_20', 'cost_at_30', 'cost_at_60','cost_at_120',
        'cost_at_300', 'last_cost', 
         'problem', 'success_rate',
      ]]

# %%
df
# Out:
#       alg  time_first_solution  cost_first_solution  cost_at_01  cost_at_05  \
# 0     RRT                900.1                 -1.0         NaN         NaN
# 1     SST                 32.4                 99.7         NaN         NaN
# 2   idbA*                  7.1                 19.7         NaN         NaN
# 3     RRT                900.1                 -1.0         NaN         NaN
# 4     SST                  4.3                 64.2         NaN         NaN
# 5   idbA*                  3.1                 13.3         NaN        13.3
# 6     RRT                 19.1                 26.1         NaN         NaN
# 7     SST                  4.3                 19.8         NaN         NaN
# 8   idbA*                  4.0                  5.4         NaN         4.9
# 9     RRT                900.0                 12.8         NaN         NaN
# 10    SST                  8.2                 11.4         NaN         NaN
# 11  idbA*                900.0                  3.0         NaN         NaN
# 12    RRT                900.0                 37.1         NaN         NaN
# 13    SST                  3.5                 41.1         NaN         NaN
# 14  idbA*                  2.0                  9.4         NaN         7.8
# 15    RRT                900.0                 37.8         NaN         NaN
# 16    SST                  4.8                 38.3         NaN         NaN
# 17  idbA*                  2.7                  8.3         NaN         8.3
#
#     cost_at_10  cost_at_20  cost_at_30  cost_at_60  cost_at_120  cost_at_300  \
# 0          NaN         NaN         NaN         NaN          NaN          NaN
# 1          NaN         NaN         NaN         NaN         96.1         94.4
# 2          NaN         NaN        18.3        18.0         17.2         17.0
# 3          NaN         NaN         NaN         NaN          NaN          NaN
# 4         64.2        58.2        55.1        55.1         50.1         43.4
# 5         11.6        11.3        10.5        10.4          9.3          9.1
# 6          NaN        22.8        22.8        22.8         22.8         22.8
# 7         18.2        16.6        16.2        14.5         12.5          8.8
# 8          4.7         4.6         4.6         4.6          4.6          4.6
# 9          NaN         NaN         NaN         NaN          NaN          NaN
# 10        11.4         8.6         8.4         6.4          5.6          3.9
# 11         NaN         NaN         NaN         NaN          NaN          NaN
# 12         NaN         NaN         NaN         NaN          NaN          NaN
# 13        41.1        35.7        31.5        30.4         27.7         18.1
# 14         7.7         6.8         6.7         6.7          6.7          6.7
# 15         NaN         NaN         NaN         NaN          NaN          NaN
# 16        32.1        30.9        30.4        25.3         22.1         14.8
# 17         7.2         7.0         6.8         6.7          6.7          6.7
#
#     last_cost                   problem  success_rate
# 0        -1.0     car_dyn_v0/Race_Track      0.133333
# 1        79.5     car_dyn_v0/Race_Track      0.800000
# 2        15.5     car_dyn_v0/Race_Track      1.000000
# 3        -1.0  car_dyn_v0/Race_Track_v1      0.266667
# 4        28.8  car_dyn_v0/Race_Track_v1      1.000000
# 5         9.1  car_dyn_v0/Race_Track_v1      1.000000
# 6        22.8  car_dyn_v0/Race_Track_v2      0.600000
# 7         5.3  car_dyn_v0/Race_Track_v2      1.000000
# 8         4.6  car_dyn_v0/Race_Track_v2      1.000000
# 9        12.8  car_dyn_v0/Race_Track_v3      0.600000
# 10        2.8  car_dyn_v0/Race_Track_v3      1.000000
# 11        3.0  car_dyn_v0/Race_Track_v3      1.000000
# 12       37.1   car_dyn_v0/narrow_short      0.666667
# 13        9.7   car_dyn_v0/narrow_short      1.000000
# 14        6.7   car_dyn_v0/narrow_short      1.000000
# 15       37.8     car_dyn_v0/val_maze_7      0.600000
# 16        8.0     car_dyn_v0/val_maze_7      1.000000
# 17        6.7     car_dyn_v0/val_maze_7      1.000000

# %%
df[df['problem']=="car_dyn_v0/Race_Track_v2"][['alg','success_rate','cost_first_solution','last_cost','time_first_solution']]
# Out:
#      alg  success_rate  cost_first_solution  last_cost  time_first_solution
# 6    RRT           0.6                 26.1       22.8                 19.1
# 7    SST           1.0                 19.8        5.3                  4.3
# 8  idbA*           1.0                  5.4        4.6                  4.0

# %%
sns.barplot(data=df, y='problem', x='cost_first_solution',hue='alg',)
# Out:
# <Axes: xlabel='cost_first_solution', ylabel='problem'>

# %%
sns.barplot(data=df, y='problem', x='cost_at_60',hue='alg',)
# Out:
# <Axes: xlabel='cost_at_60', ylabel='problem'>

# %%
sns.barplot(data=df, y='problem', x='cost_at_120',hue='alg',)
# Out:
# <Axes: xlabel='cost_at_120', ylabel='problem'>

# %%
sns.barplot(data=df, y='problem', x='cost_at_300',hue='alg',)
# Out:
# <Axes: xlabel='cost_at_300', ylabel='problem'>

# %%
df_alg = df.groupby('alg').mean(numeric_only=True).reset_index()
df_alg.round(2)[['alg','success_rate','time_first_solution','cost_first_solution','cost_at_60','last_cost']]
# Out:
#      alg  success_rate  time_first_solution  cost_first_solution  cost_at_60  \
# 0    RRT          0.48               753.22                18.63       22.80
# 1    SST          0.97                 9.58                45.75       26.34
# 2  idbA*          1.00               153.15                 9.85        9.28
#
#    last_cost
# 0      18.08
# 1      22.35
# 2       7.60

# %%
df_alg_m = df_alg.melt(id_vars=['alg', 'success_rate','time_first_solution'],  # columns to keep as-is
        var_name='cost_type',                  # new column for the old column names
        value_name='cost')                   # new column for the values
df_alg_m['cost_type'] = df_alg_m['cost_type'].str.replace("cost_at_","")
df_alg_m = df_alg_m[df_alg_m['alg']!='RRT']
df_alg_m
# Out:
#       alg  success_rate  time_first_solution            cost_type       cost
# 1     SST      0.966667             9.583333  cost_first_solution  45.750000
# 2   idbA*      1.000000           153.150000  cost_first_solution   9.850000
# 4     SST      0.966667             9.583333                   01        NaN
# 5   idbA*      1.000000           153.150000                   01        NaN
# 7     SST      0.966667             9.583333                   05        NaN
# 8   idbA*      1.000000           153.150000                   05   8.575000
# 10    SST      0.966667             9.583333                   10  33.400000
# 11  idbA*      1.000000           153.150000                   10   7.800000
# 13    SST      0.966667             9.583333                   20  30.000000
# 14  idbA*      1.000000           153.150000                   20   7.425000
# 16    SST      0.966667             9.583333                   30  28.320000
# 17  idbA*      1.000000           153.150000                   30   9.380000
# 19    SST      0.966667             9.583333                   60  26.340000
# 20  idbA*      1.000000           153.150000                   60   9.280000
# 22    SST      0.966667             9.583333                  120  35.683333
# 23  idbA*      1.000000           153.150000                  120   8.900000
# 25    SST      0.966667             9.583333                  300  30.566667
# 26  idbA*      1.000000           153.150000                  300   8.820000
# 28    SST      0.966667             9.583333            last_cost  22.350000
# 29  idbA*      1.000000           153.150000            last_cost   7.600000

# %%
ax = sns.lineplot(data=df_alg_m, x='cost_type', y='cost', hue='alg')
ax.set_title('Mean Perforamnce Over 5 Env (when solvable)');

# %%
fig, ax = plt.subplots(figsize=(6, 3))  # (width, height) in inches — adjust to taste
sns.lineplot(data=df_alg_m, x='cost_type', y='cost', hue='alg',
             palette=['orange', 'green'], ax=ax)
ax.set_title('Mean Cost(s) Over 5 Env (when solvable)')
# Out:
# Text(0.5, 1.0, 'Mean Cost(s) Over 5 Env (when solvable)')
